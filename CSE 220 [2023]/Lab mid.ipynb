# %%
#Run this cell
class Node:
  def __init__(self,elem,next=None):
    self.elem,self.next = elem,next

def create_list(arr):
  head = Node(arr[0])
  tail = head
  for i in range(1,len(arr)):
    newNode = Node(arr[i])
    tail.next = newNode
    tail = newNode
  return head

def print_linked_list(head):
  temp = head
  while temp != None:
    if temp.next != None:
      print(temp.elem, end = '-->')
    else:
      print(temp.elem)
    temp = temp.next
  print()

# %%
def check(temp, c):
  temp2=temp
  count=c
  sum=0
  while temp2 !=None and count>0:
    sum+=temp2.elem
    count-=1
    temp2=temp2.next

  return sum, temp2


def n_sum_linked_list(head, n):
  temp=head
  time=n
  summ=0
  res= True
  for i in range(n):
    sum2, hed = check(head,time)
    temp = hed
    if summ ==0:
      summ=sum2


    if summ== sum2:
      res = True
    else:
      res = False


  print(res)

# %%
def n_sum_linked_list(head, n):
    # Initialize variables
    temp = head
    current_sum = None   # Store the sum for comparison
    count = 0

    while temp is not None:
        # Calculate the sum of current window
        window_sum = 0
        for i in range(n):
            if temp is None:
                # Handle the case where the list is shorter than n elements
                return False
            window_sum += temp.elem
            temp = temp.next

        # Check if the current window sum is the same as the previous one
        if current_sum is None:
            current_sum = window_sum
        elif current_sum != window_sum:
            return False

        count += 1

    # All window sums were equal, return True
    return True

# %%
arr = [2, 4, 6, 10, 1, 1, 4, -5, 13]
head = create_list(arr)
print_linked_list(head)
print(n_sum_linked_list(head, 3))
# Expected output: True
# Out:
# 2-->4-->6-->10-->1-->1-->4-->-5-->12
#
# False
