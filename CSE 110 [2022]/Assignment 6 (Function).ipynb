# %% [markdown]
# **Task 1** : odd even number function

# %%
def even_checker(number):
  if number % 2 != 0:
    print ("Odd!!")
  else:
    print("Even!!")

even_checker(8)
even_checker(7)
# Out:
# Even!!
# Odd!!

# %%
def even_checker(num):
  if num % 2 == 0:
    print("Even!!")
  else:
    print("Odd!!")
even_checker(8)
even_checker(7)
# Out:
# Even!!
# Odd!!

# %% [markdown]
# **Task 2** : Fibonacci series

# %%
def fibonacci(number):
    back = 0
    now = 1
    x = 0
    for i in range(number + 1):
      if back <= number:
        print(back, end=' ')
        x = back + now
        back = now
        now = x

fibonacci (5)
# Out:
# 0 1 1 2 3 5

# %% [markdown]
# **Task 3 :** Foo Moo

# %%
def foo_moo(number):
    if number % 2 == 0 and number % 3 == 0:
        return "FooMoo"
    elif number % 3 == 0:
        return "Moo"
    elif number % 2 == 0:
        return "Foo"
    else:
        return "Boo"
print(foo_moo (6))
print(foo_moo (9))
print(foo_moo (8))
print(foo_moo (7))
# Out:
# FooMoo
# Moo
# Foo
# Boo

# %% [markdown]
# **Task 4 :** uppercase letters  lowercase

# %%
def upper(string1):
    upper = 0
    lower = 0
    for x in string1:
        if x >='A' and x <='Z':
            upper = upper + 1
        elif x >='a' and x <='z':
            lower = lower + 1
    print("Real String is: ", string1)
    print("Number of Upper Alphabets are: ", upper)
    print("Number of Lower Alphabets are: ", lower)
upper('The quick Sand Man')
# Out:
# Real String is:  The quick Sand Man
# Number of Upper Alphabets are:  3
# Number of Lower Alphabets are:  12

# %%
def calculate_upper_lower(string):
  lower_count = 0
  upper_count = 0
  for char in string:
    if char.isupper():
      upper_count += 1
    elif char.islower():
      lower_count += 1
  print('No. of Uppercase characters :', upper_count)
  print('No. of Lowercase Characters:', lower_count) 

calculate_upper_lower("HaRRy PotteR")
# Out:
# No. of Uppercase characters : 5
# No. of Lowercase Characters: 6

# %% [markdown]
# **task 5** : tax

# %%
age = int(input("Enter your age: "))
salary = int(input("Enter your salary: "))
job = input("Enter Job Designation: ").lower()
def calculate_tax(age,salary,job):
    if age < 18 or job == "president" or salary < 10000:
        return 0
    if(salary > 10000 and salary < 20000):
        tax= (0.05)*salary
        return tax
    else:
        tax= (0.10)*salary
        return tax
print(calculate_tax(age, salary, job))
# Out:
# Enter your age: 20
# Enter your salary: 18000
# Enter Job Designation: assistant manager
# 900.0

# %% [markdown]
# **Task 6 :** Days to year

# %%
days = int(input("Enter number of days: "))
def calculate_days(days):
  years = days // 365
  month = days % 365
  month = month// 30
  days = days % 365
  days=days % 30

  print(years, "years,", month, "months and", days, "days")
calculate_days(days)
# Out:
# Enter number of days: 4330
# 11 years, 10 months and 15 days

# %% [markdown]
# **task 7 :** palindrome

# %%
def show_palindrome(num):
    for count in range(1, num):
        print(count, end = "")
    for count2 in range(num,0,-1):
        print(count2, end = "")
show_palindrome(5)
# Out:
# 123454321

# %% [markdown]
# **task 8:** piramid pali

# %%
def show_palindromic_triangle(numm):
    for r in range(1, numm+1):
        for space in range(1, (numm-r)+1):
            print(" ",end = " ")
        for numbers in range(1, r):
            print(numbers, end = " ")
        for numbers in range(r, 0, -1):
            print(numbers, end = " ")
        print("")

show_palindromic_triangle(5)
# Out:
#         1
#       1 2 1
#     1 2 3 2 1
#   1 2 3 4 3 2 1
# 1 2 3 4 5 4 3 2 1

# %% [markdown]
# **task 9:** Area circumference generator

# %%
import math
radius=float(input("Radius of the circle: "))
def area_circumference_generator(radius):
    circumference = 2 * math.pi * radius
    area = math.pi *  math.pow(radius, 2)
    area_circumference = (area, circumference)
    return area_circumference

area, circumference = area_circumference_generator(radius)
print(area_circumference_generator(radius))
print("Area of the circle is",area, "and circumference is",circumference)
# Out:
# Radius of the circle: 2.5
# (19.634954084936208, 15.707963267948966)
# Area of the circle is 19.634954084936208 and circumference is 15.707963267948966

# %% [markdown]
# **task10:** square

# %%
def make_square(start, end):
    dict = {}
    for num in range(start, end + 1):
        dict[num] = num**2
    return dict
print(make_square(5,9))
# Out:
# {5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %% [markdown]
# task11: remove

# %%
tup=("Hi", 1, 2, 3, 3, "Hi",'a', 'a', [1,2])
def rem_duplicate(tup):
    temp_list = list(tup)
    list1 = []
    for item in temp_list:
        if item not in list1:
            list1.append(item)
    return(tuple(list1))
print(rem_duplicate(tup))
# Out:
# ('Hi', 1, 2, 3, 'a', [1, 2])

# %% [markdown]
# task12: remove ele

# %%
def remove_element(lis):
    lis_1 = []
    for x in lis:
        if lis_1.count(x)<2:
            lis_1.append(x)
        j=len(lis)-len(lis_1)
    print("Removed:",j)
    return lis_1
print(remove_element([1, 2, 3, 3, 3, 3, 4, 5, 8, 8]))
# Out:
# Removed: 2
# [1, 2, 3, 3, 4, 5, 8, 8]

# %% [markdown]
# task 13

# %%
# to do
operator= input("Enter operator: ")
first= float(input("First operand: "))
second= float(input("Enter second operand: "))
def calculate(operator, first, second):
  if operator == '+':
    a= first + second
    return a
  elif operator == '-':
    s= first - second
    return s
  elif operator == '*':
    m= first * second
    return m
  elif operator == '/':
    d= first / second
    return d

print(calculate(operator, first, second))
# Out:
# Enter operator: *
# First operand: 5.5
# Enter second operand: 2.5
# 13.75

# %% [markdown]
# task 14

# %%
user_1=input("Enter your desired sentence:").strip("'")
user_2=int(input("Enter your desired number:"))
def function_name(sentence,position):
    new_sentence=sentence[0]
    rem_word=''
    for i in range(1,len(sentence)):
        if i%position!=0:
            new_sentence=new_sentence+sentence[i]
        else:
            rem_word=rem_word+sentence[i]
    final_sentence=new_sentence+rem_word
    return final_sentence
result=function_name(user_1,user_2)
print(result)
# Out:
# Enter your desired sentence:'I love programming.'
# Enter your desired number:3
# I lveprgrmmngo oai.

# %% [markdown]
# task 15:

# %%
##################################################
orders_list = []
x=input("Enter your orders: ").lower().split(',')
for f in x:
  orders_list.append(f.strip())
def cart_list(orders):
  menu = {"rice": 105, "potato": 20, 'chicken': 250, 'beef': 510, 'oil': 85}
  total_cost = 0
  for item in orders:
    if item in menu:
      total_cost += menu[item]
  location = input("enter your location: ").lower()
  if location == "dhanmondi":
    total_cost +=30
  elif location== "":
    total_cost +=30
  else:
    total_cost += 70

  return total_cost

print(cart_list(orders_list))
# Out:
# Enter your orders: potato,beef
# enter your locationmohalhaid
# 600

# %%
def shopping_cart(order_items, location="Dhanmondi"):
    prices_list = {"Rice": 105, "Potato": 20, "Chicken": 250, "Beef": 510, "Oil": 85};
    total_ammount = 0
    for i in order_items:
        if i in prices_list.keys():
            total_ammount += prices_list[i]
    if (location == "Dhanmondi"):
        total_ammount += 30
    else:
        total_ammount += 70
    return total_ammount


print (shopping_cart (["Rice","Beef","Rice"]))
# Out:
# 750

# %%
# Out:
# 0
